# %% [markdown]
# <a href="https://colab.research.google.com/github/kovikov/CAPSTONE-PROJECT-CUSTOMER-CHURN/blob/main/pandas_lesson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# read the file
df = pd.read_csv('telecom_churn.csv')

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
# get the shape
df.shape
# Out:
# (3333, 20)

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
df.describe(include='object')
# Out:
#        State International plan Voice mail plan
# count   3333               3333            3333
# unique    51                  2               2
# top       WV                 No              No
# freq     106               3010            2411

# %%
# what is the churn distribution among the customers
df['Churn'].value_counts()
# Out:
# Churn
# False    2850
# True      483
# Name: count, dtype: int64

# %%
# for international plan
df['International plan'].value_counts()
# Out:
# International plan
# No     3010
# Yes     323
# Name: count, dtype: int64

# %%
# average time mu loyal customer are spending on the calls
df[df['Churn'] == False]['Total day minutes'].mean()
# Out:
# 175.1757543859649

# %%
# Crosstab
pd.crosstab(df['Churn'], df['International plan'])
# Out:
# International plan    No  Yes
# Churn
# False               2664  186
# True                 346  137

# %%
# crosstab
pd.crosstab(df['Churn'], df['Voice mail plan'], normalize=True)
# Out:
# Voice mail plan        No       Yes
# Churn
# False            0.602460  0.252625
# True             0.120912  0.024002

# %%
# feature engineering/ data transformation
# total calls, total minutes , total charge
df['Total calls'] = df['Total day calls'] + df['Total eve calls'] + df['Total night calls'] + df['Total intl calls']
df['Total charge'] = df['Total day charge'] + df['Total eve charge'] + df['Total night charge'] + df['Total intl charge']
df['Total minutes'] = df['Total day minutes'] + df['Total eve minutes'] + df['Total night minutes']

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# my international plan in area of yes i want to change to 1 with no i want to put 0
df.loc[df['International plan'] == 'Yes', 'International plan'] = 1
df.loc[df['International plan'] == 'No', 'International plan'] = 0

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                  0             Yes
# 1       OH             107        415                  0             Yes
# 2       NJ             137        415                  0              No
# 3       OH              84        408                  1              No
# 4       OK              75        415                  1              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                  0             Yes
# 3329    WV              68        415                  0              No
# 3330    RI              28        510                  0              No
# 3331    CT             184        510                  1              No
# 3332    TN              74        415                  0             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# Creating Aggregation Features
df["Total Minutes"] = df["Total day minutes"] + df["Total eve minutes"] + df["Total night minutes"] + df["Total intl minutes"]
df["Total Calls"] = df["Total day calls"] + df["Total eve calls"] + df["Total night calls"] + df["Total intl calls"]
df["Total Charge"] = df["Total day charge"] + df["Total eve charge"] + df["Total night charge"] + df["Total intl charge"]

# Creating Interaction Features
df["Avg Minutes per Call"] = df["Total Minutes"] / df["Total Calls"]
df["Intl Call Rate"] = df["Total intl calls"] / df["Total Calls"]
df["Service Call Intensity"] = df["Customer service calls"] / df["Account length"]

# Creating Binary Features
df["Has Voice Mail"] = df["Voice mail plan"].map({"Yes": 1, "No": 0})
df["Has International Plan"] = df["International plan"].map({"Yes": 1, "No": 0})
df["High Customer Service Calls"] = (df["Customer service calls"] > 3).astype(int)

# List of columns to drop (original ones that are transformed)
columns_to_drop = [
    "Total day minutes", "Total eve minutes", "Total night minutes", "Total intl minutes",
    "Total day calls", "Total eve calls", "Total night calls", "Total intl calls",
    "Total day charge", "Total eve charge", "Total night charge", "Total intl charge",
    "Voice mail plan", "International plan"
]

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                  0             Yes
# 1       OH             107        415                  0             Yes
# 2       NJ             137        415                  0              No
# 3       OH              84        408                  1              No
# 4       OK              75        415                  1              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                  0             Yes
# 3329    WV              68        415                  0              No
# 3330    RI              28        510                  0              No
# 3331    CT             184        510                  1              No
# 3332    TN              74        415                  0             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# Creating Ratio Features
df["Day to Night Minutes Ratio"] = df["Total day minutes"] / df["Total night minutes"]
df["Eve to Night Calls Ratio"] = df["Total eve calls"] / df["Total night calls"]
df["Intl Minutes Percentage"] = df["Total intl minutes"] / df["Total Minutes"]

# Creating Trend-based Features
df["Minutes Per Account Length"] = df["Total Minutes"] / df["Account length"]
df["Calls Per Account Length"] = df["Total Calls"] / df["Account length"]

# %%
# Display the updated dataframe with new features
# Assuming 'display' is a suitable way to show the dataframe (from IPython.display)
display(df)  # This assumes 'display' was imported with 'from IPython.display import display'

# If there is a specific function in 'tools' to display, import that:
# import tools  # Assuming tools is a custom module or package
# tools.display_dataframe_to_user(name="Updated Telecom Data", df=df)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                  0             Yes
# 1       OH             107        415                  0             Yes
# 2       NJ             137        415                  0              No
# 3       OH              84        408                  1              No
# 4       OK              75        415                  1              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                  0             Yes
# 3329    WV              68        415                  0              No
# 3330    RI              28        510                  0              No
# 3331    CT             184        510                  1              No
# 3332    TN              74        415                  0             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
print(df["International plan"].unique())
# Out:
# [0 1]

# %%
# Convert the 'International plan' column to string type before using string methods
df["International plan"] = df["International plan"].astype(str).str.strip().str.lower()
df["Has International Plan"] = df["International plan"].map({"yes": 1, "no": 0})

# %%
print(df["Has International Plan"].isna().sum())
# Out:
# 3333

# %%
df["Has International Plan"] = df["Has International Plan"].fillna(0)

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                  0             Yes
# 1       OH             107        415                  0             Yes
# 2       NJ             137        415                  0              No
# 3       OH              84        408                  1              No
# 4       OK              75        415                  1              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                  0             Yes
# 3329    WV              68        415                  0              No
# 3330    RI              28        510                  0              No
# 3331    CT             184        510                  1              No
# 3332    TN              74        415                  0             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...
